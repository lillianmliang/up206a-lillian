# %% [markdown]
# I spent my time this week looking at a couple of Zillow datasets for the group project, which was intended to be about rent gouging post-wildfire in Sonoma and Napa counties. Through this data exploration, I ended up finding that this data I originally thought promising was going to be insufficient for this project. This led my partner and I to switch directions.
#
# I looked into several [Zillow datasets](https://www.zillow.com/research/data/):
# * Zillow Observed Rent Index (ZORI)
# "Zillow Observed Rent Index (ZORI): A smoothed measure of the typical observed market rate rent across a given region. ZORI is a repeat-rent index that is weighted to the rental housing stock to ensure representativeness across the entire market, not just those homes currently listed for-rent. The index is dollar-denominated by computing the mean of listed rents that fall into the 40th to 60th percentile range for all homes and apartments in a given region, which is once again weighted to reflect the rental housing stock."
#
# * Zillow Home Value Index (ZHVI)
# "A smoothed, seasonally adjusted measure of the typical home value and market changes across a given region and housing type. It reflects the typical value for homes in the 35th to 65th percentile range. The raw version of that mid-tier ZHVI time series is also available..."

# %% [markdown]
# # ZORI
#
# First, I downloaded ZORI data at the zip code level. Unfortunately this dataset didn't contain any data for Sonoma or Napa counties. I found this out by opening the .csv in Excel and searching for some of the largest MSA's in the area - including Santa Rosa.

# %%
# first, import the geopandas library
import geopandas

# next, import the data
ZORI_zip = geopandas.read_file('../Data/Zip_ZORI_CA.csv')

# %%
ZORI_zip
# Out:
#     RegionID RegionName SizeRank                             MsaName 2014-01  \
# 0      97564      94109       14                   San Francisco, CA    2290
# 1      96107      90250       23  Los Angeles-Long Beach-Anaheim, CA    1081
# 2      97771      94565       41                   San Francisco, CA    1451
# 3      96027      90046       45  Los Angeles-Long Beach-Anaheim, CA    1705
# 4      97711      94501       89                   San Francisco, CA    1681
# ..       ...        ...      ...                                 ...     ...
# 359    96466      91708     7028                       Riverside, CA
# 360    96234      90755     7127  Los Angeles-Long Beach-Anaheim, CA
# 361    96946      92610     7249  Los Angeles-Long Beach-Anaheim, CA    2202
# 362    96087      90211     7515  Los Angeles-Long Beach-Anaheim, CA    1955
# 363    96979      92661     8589  Los Angeles-Long Beach-Anaheim, CA    2002
#
#     2014-02 2014-03 2014-04 2014-05 2014-06  ... 2021-01 2021-02 2021-03  \
# 0      2336    2382    2428    2473    2518  ...    2654    2645    2635
# 1      1084    1087    1090    1094    1097  ...    1689    1696    1702
# 2                      1501    1518    1534  ...    2415    2432    2449
# 3      1726    1747    1769    1788    1808  ...    2359    2367    2374
# 4      1697    1713    1729            1760  ...    2321    2328    2334
# ..      ...     ...     ...     ...     ...  ...     ...     ...     ...
# 359            2133    2134    2135    2136  ...    2759    2808    2857
# 360                    1615                  ...    2266    2280    2293
# 361    2205    2208            2216    2221  ...    2727    2759    2791
# 362    2011    2066    2122    2174    2225  ...    2993    2990    2987
# 363                    2143                  ...    3782    3841    3899
#
#     2021-04 2021-05 2021-06 2021-07 2021-08 2021-09 geometry
# 0      2626    2619    2613    2606    2603    2600     None
# 1      1708    1715    1721    1727    1734    1740     None
# 2      2466    2483    2500    2518    2536    2555     None
# 3      2382    2391    2400    2409    2419    2429     None
# 4      2340    2346    2353    2359    2366    2373     None
# ..      ...     ...     ...     ...     ...     ...      ...
# 359    2905    2955    3005    3055    3107    3159     None
# 360    2307    2321    2335    2350    2365             None
# 361    2824    2857    2890    2923    2958    2993     None
# 362    2983    2980    2977    2974    2972    2970     None
# 363    3958    4019    4079    4140    4201    4261     None
#
# [364 rows x 98 columns]

# %% [markdown]
# ## ZHVI Neighborhood
# When the above was leading to a dead end, I tried to look at the home value index. It turns out that the home values cover a wider geographical area than the rent market. Below I'm importing and exploring the data.

# %%
# first, import the geopandas library
import geopandas as gpd

# next, import the data
ZHVI_neighborhood = geopandas.read_file('../Data/Neighborhood_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')

# %%
ZHVI_neighborhood.shape
# Out:
# (16410, 270)

# %%
ZHVI_neighborhood.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 16410 entries, 0 to 16409
# Columns: 270 entries, RegionID to geometry
# dtypes: geometry(1), object(269)
# memory usage: 33.8+ MB

# %%
ZHVI_neighborhood.head()
# Out:
#   RegionID SizeRank         RegionName    RegionType StateName State  \
# 0   274772        0   Northeast Dallas  Neighborhood        TX    TX
# 1   112345        1           Maryvale  Neighborhood        AZ    AZ
# 2   192689        2           Paradise  Neighborhood        NV    NV
# 3   270958        3    Upper West Side  Neighborhood        NY    NY
# 4   118208        4  South Los Angeles  Neighborhood        CA    CA
#
#           City                           Metro          CountyName 2000-01-31  \
# 0       Dallas     Dallas-Fort Worth-Arlington       Dallas County   152919.0
# 1      Phoenix         Phoenix-Mesa-Scottsdale     Maricopa County    83271.0
# 2    Las Vegas    Las Vegas-Henderson-Paradise        Clark County   152657.0
# 3     New York     New York-Newark-Jersey City     New York County   391890.0
# 4  Los Angeles  Los Angeles-Long Beach-Anaheim  Los Angeles County   154000.0
#
#    ... 2020-12-31 2021-01-31 2021-02-28 2021-03-31 2021-04-30 2021-05-31  \
# 0  ...   352199.0   356725.0   362165.0   367250.0   371000.0   374851.0
# 1  ...   221874.0   227592.0   230860.0   236779.0   241819.0   250354.0
# 2  ...   292090.0   295361.0   298475.0   301960.0   306035.0   313424.0
# 3  ...  1381298.0  1371749.0  1366293.0  1358496.0  1372387.0  1374302.0
# 4  ...   579954.0   582101.0   587633.0   595565.0   604113.0   614690.0
#
#   2021-06-30 2021-07-31 2021-08-31 geometry
# 0   380332.0   385945.0   395018.0     None
# 1   257117.0   264016.0   269076.0     None
# 2   323097.0   332994.0   341428.0     None
# 3  1373921.0  1375277.0  1386160.0     None
# 4   626421.0   641772.0   653719.0     None
#
# [5 rows x 270 columns]

# %% [markdown]
# Then I filtered for the counties in question.

# %%
ZHVI_neighborhood_Napa_Sonoma = ZHVI_neighborhood[(ZHVI_neighborhood['State']=='CA')& ((ZHVI_neighborhood['CountyName']=='Sonoma County') |(ZHVI_neighborhood['CountyName']=='Napa County'))]
ZHVI_neighborhood_Napa_Sonoma
# Out:
#       RegionID SizeRank             RegionName    RegionType StateName State  \
# 2291    396534     2353       Larkfield-Wikiup  Neighborhood        CA    CA
# 2520    763792     2589            Pueblo Park  Neighborhood        CA    CA
# 2704    223728     2777               Westwood  Neighborhood        CA    CA
# 3578    763787     3662              Shurtleff  Neighborhood        CA    CA
# 3939    136125     4032                Central  Neighborhood        CA    CA
# 4544    261871     4655              Mcpherson  Neighborhood        CA    CA
# 4815    763782     4925            Fuller Park  Neighborhood        CA    CA
# 5034    763793     5148               Bel Aire  Neighborhood        CA    CA
# 5094    763798     5208       Vineyard Estates  Neighborhood        CA    CA
# 5859    763797     5992            Linda Vista  Neighborhood        CA    CA
# 5933    763788     6070           Alta Heights  Neighborhood        CA    CA
# 5982    763795     6120             Stonehouse  Neighborhood        CA    CA
# 6115    216699     6254                Vintage  Neighborhood        CA    CA
# 6224    763791     6366                  Beard  Neighborhood        CA    CA
# 6289    763781     6429     Browns Valley East  Neighborhood        CA    CA
# 6314    116825     6455             Napa Abajo  Neighborhood        CA    CA
# 6527    763794     6679        Von Uhlit Ranch  Neighborhood        CA    CA
# 7113    763796     7288     Springwood Estates  Neighborhood        CA    CA
# 8239    763786     8454   Soscol Gateway South  Neighborhood        CA    CA
# 9064    763799     9317    Browns Valley South  Neighborhood        CA    CA
# 9306    761259     9571        Corby-Beachwood  Neighborhood        CA    CA
# 10395   763759    10720  Browns Valley Central  Neighborhood        CA    CA
# 10917   763783    11265         Coventry Manor  Neighborhood        CA    CA
# 11225   763789    11600               Downtown  Neighborhood        CA    CA
# 11496   415721    11889                Terrace  Neighborhood        CA    CA
# 11583   761458    11980          Sunset McMinn  Neighborhood        CA    CA
# 11735   761260    12139            Olive Corby  Neighborhood        CA    CA
# 12348   763780    12789     Browns Valley West  Neighborhood        CA    CA
# 12642   761262    13106             South Park  Neighborhood        CA    CA
# 14621   761261    15221              Aston Ave  Neighborhood        CA    CA
# 14677   763785    15282              Riverpark  Neighborhood        CA    CA
# 15191   763784    15835        Sheveland Ranch  Neighborhood        CA    CA
# 16407   117010    17008                Oakmont  Neighborhood        CA    CA
#
#              City       Metro     CountyName 2000-01-31  ... 2020-12-31  \
# 2291   Santa Rosa  Santa Rosa  Sonoma County   279813.0  ...   713835.0
# 2520         Napa        Napa    Napa County   199007.0  ...   638433.0
# 2704         Napa        Napa    Napa County   167241.0  ...   548105.0
# 3578         Napa        Napa    Napa County   192909.0  ...   611400.0
# 3939         Napa        Napa    Napa County   188945.0  ...   702848.0
# 4544         Napa        Napa    Napa County   170880.0  ...   621506.0
# 4815         Napa        Napa    Napa County   195557.0  ...   740427.0
# 5034         Napa        Napa    Napa County   215269.0  ...   635868.0
# 5094         Napa        Napa    Napa County   292779.0  ...   795914.0
# 5859         Napa        Napa    Napa County   264740.0  ...   747974.0
# 5933         Napa        Napa    Napa County   295281.0  ...   835056.0
# 5982         Napa        Napa    Napa County   181387.0  ...   661082.0
# 6115         Napa        Napa    Napa County   254661.0  ...   678797.0
# 6224         Napa        Napa    Napa County   185058.0  ...   582866.0
# 6289         Napa        Napa    Napa County   301448.0  ...   836368.0
# 6314         Napa        Napa    Napa County   191473.0  ...   660484.0
# 6527         Napa        Napa    Napa County   184424.0  ...   604185.0
# 7113         Napa        Napa    Napa County   228379.0  ...   745538.0
# 12348   852517.0   864633.0   869368.0   878979.0   894494.0   917768.0
# 12642   497280.0   499654.0   501098.0   507020.0   514177.0   524914.0
# 14621   500127.0   503448.0   509332.0   515358.0   522038.0   528896.0
# 14677   957909.0   974584.0   981963.0   992674.0  1007652.0  1042518.0
# 15191   581590.0   589452.0   589902.0   594797.0   604278.0   626715.0
# 16407   653554.0   653144.0   656615.0   662062.0   666511.0   669824.0
#
#       2021-07-31 2021-08-31 geometry
# 2291    758879.0   773850.0     None
# 2520    715431.0   729420.0     None
# 2704    613312.0   627593.0     None
# 3578    671133.0   679919.0     None
# 3939    779692.0   791484.0     None
# 4544    696702.0   711041.0     None
# 4815    816441.0   828589.0     None
# 5034    699149.0   714466.0     None
# 5094    891261.0   913592.0     None
# 5859    825702.0   843179.0     None
# 5933    948319.0   969540.0     None
# 5982    738881.0   753438.0     None
# 6115    757854.0   778464.0     None
# 6224    650753.0   665890.0     None
# 6289    937324.0   960415.0     None
# 6314    715241.0   723856.0     None
# 6527    676278.0   690087.0     None
# 7113    834110.0   853967.0     None
# 8239    873355.0   888730.0     None
# 9064   1015398.0  1040545.0     None
# 9306    548330.0   553970.0     None
# 10395  1001158.0  1022914.0     None
# 10917   679349.0   695048.0     None
# 11225   843365.0   860864.0     None
# 11496   899962.0   913864.0     None
# 11583   554972.0   561410.0     None
# 11735   531950.0   541679.0     None
# 12348   941768.0   964285.0     None
# 12642   534213.0   544982.0     None
# 14621   539895.0   550023.0     None
# 14677  1071870.0  1096701.0     None
# 15191   645426.0   663240.0     None
# 16407   676143.0   684258.0     None
#
# [33 rows x 270 columns]

# %%
# reset the index
ZHVI_neighborhood_Napa_Sonoma.reset_index()

# check datatypes
ZHVI_neighborhood_Napa_Sonoma.dtypes
# Out:
# RegionID        object
# SizeRank        object
# RegionName      object
# RegionType      object
# StateName       object
#                 ...
# 2021-05-31      object
# 2021-06-30      object
# 2021-07-31      object
# 2021-08-31      object
# geometry      geometry
# Length: 270, dtype: object

# %% [markdown]
# I noticed that most of the entries that are supposed to have numerical data are currently objects and set out to try to change them.

# %%
# all the data starts at column indexed 9. 
ZHVI_neighborhood_Napa_Sonoma_data = ZHVI_neighborhood_Napa_Sonoma.iloc[:,9:]
# for rows 9 to end, convert the data type to a float. I accessed these with iloc.

# Get the second dimension of the data array
print(ZHVI_neighborhood_Napa_Sonoma_data.shape[1])

for x in range(ZHVI_neighborhood_Napa_Sonoma_data.shape[1]):
    ZHVI_neighborhood_Napa_Sonoma_data.iloc[:,x] = ZHVI_neighborhood_Napa_Sonoma_data.iloc[:,x].astype(float)
ZHVI_neighborhood_Napa_Sonoma_data.dtypes
# Out:
# 261
# 2000-01-31    float64
# 2000-02-29    float64
# 2000-03-31    float64
# 2000-04-30    float64
# 2000-05-31    float64
#                ...
# 2021-05-31    float64
# 2021-06-30    float64
# 2021-07-31    float64
# 2021-08-31    float64
# geometry      float64
# Length: 261, dtype: object

# %% [markdown]
# There! The datatypes are converted.
